# %% [markdown]
# *The maps in this notebook will not be shown on GitHub, but it is possible to see the rendered notebook here:* https://nbviewer.org/github/tkatus/demos/blob/main/Crime_London.ipynb
#
# # Crime in London
#
# The Metropolitan Police reports monthly updated crime figures for London's boroughs.

# %%
import pandas as pd
import folium
import re

url = 'https://data.london.gov.uk/download/recorded_crime_summary/d2e9ccfc-a054-41e3-89fb-53c2bc3ed87a/MPS%20Borough%20Level%20Crime%20%28most%20recent%2024%20months%29.csv' 
cDF = pd.read_csv(url)
cDF.set_index('LookUp_BoroughName', inplace = True)
cDF.head()
# Out:
#                                       MajorText  \
# LookUp_BoroughName
# Barking and Dagenham  Arson and Criminal Damage
# Barking and Dagenham  Arson and Criminal Damage
# Barking and Dagenham                   Burglary
# Barking and Dagenham                   Burglary
# Barking and Dagenham              Drug Offences
#
#                                             MinorText  202005  202006  202007  \
# LookUp_BoroughName
# Barking and Dagenham                            Arson       2       4       4
# Barking and Dagenham                  Criminal Damage      86     120     123
# Barking and Dagenham  Burglary Business and Community      16      16      28
# Barking and Dagenham                Domestic Burglary      42      63      72
# Barking and Dagenham                 Drug Trafficking      17      10      21
#
#                       202008  202009  202010  202011  202012  ...  202107  \
# LookUp_BoroughName                                            ...
# Barking and Dagenham       6       2       7       4       2  ...       4
# Barking and Dagenham     114     116     120     100     110  ...     130
# Barking and Dagenham      23      32      20      18      24  ...      21
# Barking and Dagenham      63      54      68      90      91  ...      61
# Barking and Dagenham      10      12      14      18      13  ...       6
#
#                       202108  202109  202110  202111  202112  202201  202202  \
# LookUp_BoroughName
# Barking and Dagenham      12       5       7       6       1       4       4
# Barking and Dagenham     143     111     126     109     116     126     110
# Barking and Dagenham      29      27      37      20      14      19      29
# Barking and Dagenham      87      62      82      87      91      81      67
# Barking and Dagenham       9      15      17       9      11      15      11
#
#                       202203  202204
# LookUp_BoroughName
# Barking and Dagenham       3       5
# Barking and Dagenham     117     126
# Barking and Dagenham      30      18
# Barking and Dagenham      76      83
# Barking and Dagenham      19      13
#
# [5 rows x 26 columns]

# %% [markdown]
# GPS locations of London's boroughs are publicly available on wikipedia.

# %%
def londonBuroughs():
    url = r'https://en.wikipedia.org/wiki/List_of_London_boroughs'
    tempo = pd.read_html(url) # , match = 'List of boroughs and local authorities')    
    # add city of london to list 
    d = tempo[0]
    tempo[1].columns = d.columns        # the two tables have slightly different columns, so for now use the columsn of the main table
    d.loc[len(d)+1] = tempo[1].iloc[0]   # add city of london

# Cleaning the data
    # remove square and round brackets
    df = d['Borough'].str.extract(r'([\w ]*)')
    df.columns = ['boroughs']
    df['local authority'] = d['Local authority'].str.extract(r'([\w ]*)')
    df['political control'] = d['Political control'].str.extract(r'([\w]*)') # use single word
    df['area'] = d['Area (sq mi)']
    df['population'] = d['Population (2019 est)[1]']
        
# parsing GPS coordinates
    def convert2GPS(thisCoord):
        tempo = float(thisCoord[0][0])
        if thisCoord[0][1] in ['S', 'W']:  # make negative if East or South
            tempo = -1 * tempo 
        return tempo

    lats = []; lngs=[]
    for idx, row in d.iterrows():
        x = re.search(r'\ufeff\d', row['Co-ordinates']) # find second GPS coordinate (1st one is no good)
        x = row['Co-ordinates'][x.span()[1]-1:]
        lng = re.findall(r'([0-9.]+)°([NS]{1})',x)
        lat = re.findall(r'([0-9.]+)°([EW]{1})',x)        
        lats.append(convert2GPS(lat))
        lngs.append(convert2GPS(lng))

    df['longitude'] = lngs
    df['latitude'] = lats
    df.set_index('boroughs', inplace=True)
    return df

bDF = londonBuroughs()
print('DataFrame bDF lists the boroughs of London, the GPS coordinates of their HQs and some basic demographic information (e.g., population)')
bDF.head()
# Out:
# DataFrame bDF lists the boroughs of London, the GPS coordinates of their HQs and some basic demographic information (e.g., population)
#                                                   local authority  \
# boroughs
# Barking and Dagenham  Barking and Dagenham London Borough Council
# Barnet                              Barnet London Borough Council
# Bexley                              Bexley London Borough Council
# Brent                                Brent London Borough Council
# Bromley                            Bromley London Borough Council
#
#                      political control   area  population  longitude  latitude
# boroughs
# Barking and Dagenham            Labour  13.93      212906    51.5607    0.1557
# Barnet                          Labour  33.49      395896    51.6252   -0.1517
# Bexley                    Conservative  23.38      248287    51.4549    0.1505
# Brent                           Labour  16.70      329771    51.5588   -0.2817
# Bromley                   Conservative  57.97      332336    51.4039    0.0198

# %% [markdown]
# ------------
#
# __Basic map__ Plot borough population in an interactive pop-up map.

# %%
centerGPSCoord = (51.509865, -0.15) 

m = folium.Map(location = centerGPSCoord, zoom_start=11)
for idx, row in bDF.iterrows():
    if idx == 'City of London':
        col = 'black'
    else:
        col = 'blue'
        
    folium.CircleMarker(
        fill_color='white',
        radius = 10,         
        location = [row.longitude, row.latitude],        
        color=col, 
        opacity = 1,
        fill_opacity = .3,
        fill=True, 
        popup =  idx + ' ' + str(round(row.population/1000)) + 'k').add_to(m)
       
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d8bd74532df1ea2bcff63afbf3a69c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d8bd74532df1ea2bcff63afbf3a69c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7d8bd74532df1ea2bcff63afbf3a69c5 = L.map(
#                 &quot;map_7d8bd74532df1ea2bcff63afbf3a69c5&quot;,
#                 {
#                     center: [51.509865, -0.15],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af850879542779f9845860b8bf657546 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d8bd74532df1ea2bcff63afbf3a69c5);
#
#
#             var circle_marker_4e52a98617e0f5be05eef2fdf5a3492a = L.circleMarker(
#                 [51.5607, 0.1557],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7d8bd74532df1ea2bcff63afbf3a69c5);
#
#
#         var popup_d19eb42fa7890a0a73257c2c572b6f1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_44e7983184d31e4a7df636b9df791fda = $(`&lt;div id=&quot;html_44e7983184d31e4a7df636b9df791fda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barking and Dagenham 213k&lt;/div&gt;`)[0];
#             popup_d19eb42fa7890a0a73257c2c572b6f1f.setContent(html_44e7983184d31e4a7df636b9df791fda);
#
#
#         circle_marker_4e52a98617e0f5be05eef2fdf5a3492a.bindPopup(popup_d19eb42fa7890a0a73257c2c572b6f1f)
#         ;
#
#
#
#
#             var circle_marker_507ef8557ff87db36e2e01e0d3626cf6 = L.circleMarker(
#                 [51.6252, -0.1517],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7d8bd74532df1ea2bcff63afbf3a69c5);
#
#
#         var popup_c02270a7bb9fb02cee5b2a0bd97152fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_afcc732fc02d2e7f78fac8e8a7961063 = $(`&lt;div id=&quot;html_afcc732fc02d2e7f78fac8e8a7961063&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barnet 396k&lt;/div&gt;`)[0];
#             popup_c02270a7bb9fb02cee5b2a0bd97152fe.setContent(html_afcc732fc02d2e7f78fac8e8a7961063);
#
#
#         circle_marker_507ef8557ff87db36e2e01e0d3626cf6.bindPopup(popup_c02270a7bb9fb02cee5b2a0bd97152fe)
#         ;
#
#
#
#
#             var circle_marker_e4f643c6790d34557153bfb86af87589 = L.circleMarker(
#                 [51.4549, 0.1505],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7d8bd74532df1ea2bcff63afbf3a69c5);
#
#
#         var popup_a2efb2da16a28a06e88f0f988c20567d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c0a3b475cff8ac6a2331d58c9ccf3542 = $(`&lt;div id=&quot;html_c0a3b475cff8ac6a2331d58c9ccf3542&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bexley 248k&lt;/div&gt;`)[0];
#             popup_a2efb2da16a28a06e88f0f988c20567d.setContent(html_c0a3b475cff8ac6a2331d58c9ccf3542);
#
#
#         circle_marker_e4f643c6790d34557153bfb86af87589.bindPopup(popup_a2efb2da16a28a06e88f0f988c20567d)
#         ;
#
#
#
#
#             var circle_marker_3b588246c36c494edc899a6dd40db4cd = L.circleMarker(
#                 [51.5588, -0.2817],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10, &quot;strok

# %% [markdown]
# _________
# __Crime map__ Plot crime per capita in map.

# %%
print('DataFrame cDF reports crime stats per borough. Offences reported by the MET police:\n')
print(sorted(list(set(cDF['MinorText']))))
# Out:
# DataFrame cDF reports crime stats per borough. Offences reported by the MET police:
#
# ['Absconding from Lawful Custody', 'Aggravated Vehicle Taking', 'Aiding Suicide', 'Arson', 'Bail Offences', 'Bicycle Theft', 'Bigamy', 'Burglary Business and Community', 'Criminal Damage', 'Dangerous Driving', 'Disclosure, Obstruction, False or Misleading State', 'Domestic Burglary', 'Drug Trafficking', 'Exploitation of Prostitution', 'Forgery or Use of Drug Prescription', 'Fraud or Forgery Associated with Driver Records', 'Going Equipped for Stealing', 'Handling Stolen Goods', 'Homicide', 'Interfering with a Motor Vehicle', 'Making, Supplying or Possessing Articles for use i', 'Obscene Publications', 'Offender Management Act', 'Other Firearm Offences', 'Other Forgery', 'Other Knife Offences', 'Other Notifiable Offences', 'Other Offences Against the State, or Public Order', 'Other Sexual Offences', 'Other Theft', 'Perjury', 'Perverting Course of Justice', 'Possession of Article with Blade or Point', 'Possession of Drugs', 'Possession of False Documents', 'Possession of Firearm with Intent', 'Possession of Firearms Offences', 'Possession of Other Weapon', 'Profitting From or Concealing Proceeds of Crime', 'Public Fear Alarm or Distress', 'Racially or Religiously Aggravated Public Fear, Al', 'Rape', 'Robbery of Business Property', 'Robbery of Personal Property', 'Shoplifting', 'Soliciting for Prostitution', 'Theft from Person', 'Theft from a Motor Vehicle', 'Theft or Taking of a Motor Vehicle', 'Threat or Possession With Intent to Commit Crimina', 'Violence with Injury', 'Violence without Injury', 'Violent Disorder', 'Wildlife Crime']

# %%
# CHANGE THIS VARIABLE to look at a different type of crime
thisCrime = 'Theft or Taking of a Motor Vehicle'  
# --------------------------------------------------------
markerSizes = [5, 30]

a = cDF[cDF['MinorText'] == thisCrime][cDF.columns[-1]]                   # last column has the data from the most recent month   
c = bDF.merge(a, how='left', left_on='boroughs', right_on='LookUp_BoroughName', right_index=True) # allow missing values as long as there are GPS coordinates
c.columns = list(c.columns[:-1]) + ['crimes']
c['perCapita'] = c.crimes / c.population

# get colors to represent ruling party
def party2col(x): # political control
    cm = []
    for zed in x:
        if zed == 'Labour':
            cm.append('red')
        elif zed == 'Conservative':
            cm.append('blue')
        elif zed == 'Liberal':
            cm.append('orange')
        elif zed == 'Green':
            cm.append('green')
        else: 
            cm.append('gray')
    return cm

# map perCapita crimes so that min and max values match range determined by markerSizes
def scaleValues(x, markerSizes):
    # scale variable range to 0-1
    x = (x - x.min())
    x = x / x.max()    
    # scale to min - max markerSizes
    return x * (max(markerSizes) - min(markerSizes)) + min(markerSizes)

c['markerCol'] = party2col(bDF['political control'])
c['markerSize'] = scaleValues(c['perCapita'], markerSizes)
c.head()

# PLOT -------
c = c.dropna()
centerGPSCoord = (51.509865, -0.15) 

m = folium.Map(location = centerGPSCoord, zoom_start=11)
for idx, row in c.iterrows():        
    folium.CircleMarker(
        fill_color='white',
        radius = row.markerSize,         
        location = [row.longitude, row.latitude],        
        color = row.markerCol, 
        opacity = 1,
        fill_opacity = .3,
        fill=True, 
        popup =  idx + ' pop = ' + str(round(row.population/1000)) + 'k crimes = ' + str(int(row.crimes))).add_to(m)

print('Crime: ', thisCrime)
display(m)
# Out:
# Crime:  Theft or Taking of a Motor Vehicle
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34fe95897381833b727a379cb7e74e9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34fe95897381833b727a379cb7e74e9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_34fe95897381833b727a379cb7e74e9d = L.map(
#                 &quot;map_34fe95897381833b727a379cb7e74e9d&quot;,
#                 {
#                     center: [51.509865, -0.15],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1dcfb33fc6b67adee7381296470ee9f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_34fe95897381833b727a379cb7e74e9d);
#
#
#             var circle_marker_9c503966ca4b8c0023366db3e1f1def4 = L.circleMarker(
#                 [51.5607, 0.1557],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 30.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_34fe95897381833b727a379cb7e74e9d);
#
#
#         var popup_d241fc90e875b3933a3e9518b0df9f75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_96cf7e7986364a858d3dedee6d52b0e8 = $(`&lt;div id=&quot;html_96cf7e7986364a858d3dedee6d52b0e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barking and Dagenham pop = 213k crimes = 111&lt;/div&gt;`)[0];
#             popup_d241fc90e875b3933a3e9518b0df9f75.setContent(html_96cf7e7986364a858d3dedee6d52b0e8);
#
#
#         circle_marker_9c503966ca4b8c0023366db3e1f1def4.bindPopup(popup_d241fc90e875b3933a3e9518b0df9f75)
#         ;
#
#
#
#
#             var circle_marker_67336d5bcc93a0e89ae750b93ceac4ea = L.circleMarker(
#                 [51.6252, -0.1517],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 17.8088982619945, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_34fe95897381833b727a379cb7e74e9d);
#
#
#         var popup_3d5ea91af87fc3dbbb597d861f3ded75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c0505ee63d3e35ff0eff25a35a40ca91 = $(`&lt;div id=&quot;html_c0505ee63d3e35ff0eff25a35a40ca91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barnet pop = 396k crimes = 135&lt;/div&gt;`)[0];
#             popup_3d5ea91af87fc3dbbb597d861f3ded75.setContent(html_c0505ee63d3e35ff0eff25a35a40ca91);
#
#
#         circle_marker_67336d5bcc93a0e89ae750b93ceac4ea.bindPopup(popup_3d5ea91af87fc3dbbb597d861f3ded75)
#         ;
#
#
#
#
#             var circle_marker_991b7627996f500c2bea1139f17b87ea = L.circleMarker(
#                 [51.4549, 0.1505],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 12.72738064419589, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_34fe95897381833b727a379cb7e74e9d);
#
#
#         var popup_8332c9a68191c24ba09a301b658a9fa8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6ebec56646fe599f6cf10489cb25dabd = $(`&lt;div id=&quot;html_6ebec56646fe599f6cf10489cb25dabd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bexley pop = 248k crimes = 66&lt;/div&gt;`)[0];
#             popup_8332c9a68191c24ba09a301b658a9fa8.setContent(html_6ebec56646fe599f6cf10489cb25dabd);
#
#
#         circle_marker_991b7627996f500c2bea1139f17b87ea.bindPopup(popup_8332c9a68191c24ba09a301b658a9fa8)
#         ;
#
#
#
#
#             var circle_marker_44bcc3f800b4d9bfbc505110f54fa2d6 = L.circleMarker(
#                 [51.5588, -0.2817],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&q

# %% [markdown]
# The sizes of the circles indicate crimes per Capita. Their colours indicate the currently ruling party (red for Labour, blue for Tories, orange for LibDems, green for Green, gray for other).
#
#
# ----------------
# __TBC__ (work in progress) - Choropleth is next
